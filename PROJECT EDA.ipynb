# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\jacks\\Downloads\\EDA-Project-main\\EDA-Project-main\\DataSet.csv")
df
# Out:
#       Unnamed: 0   Age  Gender    Education Level              Job Title  \
# 0              0  32.0    Male         Bachelor's      Software Engineer
# 1              1  28.0  Female           Master's           Data Analyst
# 2              2  45.0    Male                PhD         Senior Manager
# 3              3  36.0  Female         Bachelor's        Sales Associate
# 4              4  52.0    Male           Master's               Director
# ...          ...   ...     ...                ...                    ...
# 6699        6699  49.0  Female                PhD  Director of Marketing
# 6700        6700  32.0    Male        High School        Sales Associate
# 6701        6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702        6702  46.0    Male    Master's Degree      Marketing Manager
# 6703        6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Age  Gender Education Level          Job Title  \
# 0           0  32.0    Male      Bachelor's  Software Engineer
# 1           1  28.0  Female        Master's       Data Analyst
# 2           2  45.0    Male             PhD     Senior Manager
# 3           3  36.0  Female      Bachelor's    Sales Associate
# 4           4  52.0    Male        Master's           Director
#
#    Years of Experience    Salary Country      Race
# 0                  5.0   90000.0      UK     White
# 1                  3.0   65000.0     USA  Hispanic
# 2                 15.0  150000.0  Canada     White
# 3                  7.0   60000.0     USA  Hispanic
# 4                 20.0  200000.0     USA     Asian

# %%
df.shape
# Out:
# (6704, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Gender', 'Education Level', 'Job Title',
#        'Years of Experience', 'Salary', 'Country', 'Race'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# Country                0
# Race                   0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
df
# Out:
#       Unnamed: 0   Age  Gender    Education Level              Job Title  \
# 0              0  32.0    Male         Bachelor's      Software Engineer
# 1              1  28.0  Female           Master's           Data Analyst
# 2              2  45.0    Male                PhD         Senior Manager
# 3              3  36.0  Female         Bachelor's        Sales Associate
# 4              4  52.0    Male           Master's               Director
# ...          ...   ...     ...                ...                    ...
# 6699        6699  49.0  Female                PhD  Director of Marketing
# 6700        6700  32.0    Male        High School        Sales Associate
# 6701        6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702        6702  46.0    Male    Master's Degree      Marketing Manager
# 6703        6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# ...

# %%
df = df.drop(labels = ['Unnamed: 0'],axis = 1)
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary Country      Race
# 0   90000.0      UK     White
# 1   65000.0     USA  Hispanic
# 2  150000.0  Canada     White
# 3   60000.0     USA  Hispanic
# 4  200000.0     USA     Asian

# %%
df.nunique()
# Out:
# Age                     41
# Gender                   3
# Education Level          7
# Job Title              191
# Years of Experience     37
# Salary                 444
# Country                  5
# Race                    10
# dtype: int64

# %%
df['Education Level'].unique()
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# 0                     5.0   90000.0         UK       White
# 1                     3.0   65000.0        USA    Hispanic
# ...

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6698.000000          6698.000000    6698.000000
# mean     33.623022             8.095178  115329.253061
# std       7.615784             6.060291   52789.792507
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df.describe().T
# Out:
#                       count           mean           std    min      25%  \
# Age                  6698.0      33.623022      7.615784   21.0     28.0
# Years of Experience  6698.0       8.095178      6.060291    0.0      3.0
# Salary               6698.0  115329.253061  52789.792507  350.0  70000.0
#
#                           50%       75%       max
# Age                      32.0      38.0      62.0
# Years of Experience       7.0      12.0      34.0
# Salary               115000.0  160000.0  250000.0

# %% [markdown]
# ## EDA
# ## FOR PIE CHART
# ## STEP 1 DROP MISSING VALUES FROM GENDER COULMN AND COUNT VALUES IN IT

# %%
gender_count = df['Gender'].dropna().value_counts()
gender_count
# Out:
# Gender
# Male      3671
# Female    3013
# Other       14
# Name: count, dtype: int64

# %% [markdown]
# ## STEP 2 NOW PLOT THE PIE CHART ON THIS
# ## GIVE THE SIZE OF CHART YOU WANT TO PLOT
# ## THEN GIVE

# %%
plt.figure(figsize=(7,7))
plt.pie(gender_count,labels=gender_count.index,autopct='%1.1f%%',startangle=150,colors=['lightblue','lightcoral'])
plt.axis('equal')
plt.show()

# %% [markdown]
# ## HISTOGRAM FOR AGES DISTRIBUTION

# %%
age_distri = df['Age'].dropna().value_counts()
age_distri
# Out:
# Age
# 27.0    516
# 30.0    449
# 29.0    444
# 28.0    429
# 33.0    398
# 26.0    393
# 31.0    364
# 32.0    351
# 34.0    309
# 25.0    284
# 36.0    281
# 24.0    240
# 35.0    200
# 42.0    176
# 43.0    158
# 39.0    158
# 37.0    156
# 38.0    149
# 45.0    144
# 41.0    129
# 44.0    126
# 23.0    104
# 46.0    102
# 48.0     98
# 40.0     92
# 49.0     91
# 50.0     88
# 54.0     68
# 47.0     47
# 51.0     30
# 52.0     29
# 21.0     18
# 55.0     16
# 22.0     15
# 56.0     11
# 57.0      9
# 53.0      7
# 58.0      7
# 62.0      5
# 60.0      5
# 61.0      2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(age_distri,bins=40,kde=True,color='blue')

plt.title('AGE  DISTRIBUTION')
plt.xlabel('no of people')
plt.ylabel('Frequency of their age')
plt.show()

# %% [markdown]
# ## COUNT PLOT FOR DISTRIBUTION OF EDUCATION LEVELS

# %%
edu_levels = df['Education Level'].dropna().value_counts()
edu_levels
# Out:
# Education Level
# Bachelor's Degree    2265
# Master's Degree      1572
# PhD                  1368
# Bachelor's            756
# High School           448
# Master's              288
# phD                     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(11,9))
sns.countplot(edu_levels,palette='pastel')
plt.title('EDUCATION DISTRIBUTION')
plt.xlabel('EDUCATION LEVEL')
plt.ylabel('Count')
plt.title('education  DISTRIBUTION')
plt.xlabel('EDUCATION LEVEL')
plt.ylabel('Frequency')

plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ## COUNTPLOT FOR JOB TITLE

# %%
job_title = df['Job Title'].dropna().value_counts()
job_title
# Out:
# Job Title
# Software Engineer             518
# Data Scientist                453
# Software Engineer Manager     376
# Data Analyst                  363
# Senior Project Engineer       318
#                              ...
# Account Manager                 1
# Help Desk Analyst               1
# Senior Training Specialist      1
# Junior Web Designer             1
# Software Project Manager        1
# Name: count, Length: 191, dtype: int64

# %%
plt.figure(figsize=(11,9))
sns.countplot(job_title,palette='pastel')

plt.title('JOB TITLE DISTRIBUTION')
plt.xlabel('JOB TITLE')
plt.ylabel('Count')



plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# ## HISTOGRAM FOR YEARS OF EXPERIENCE

# %%
yr_exp = df['Years of Experience'].dropna().value_counts()
yr_exp
# Out:
# Years of Experience
# 2.0     610
# 3.0     602
# 1.0     540
# 4.0     522
# 6.0     438
# 8.0     425
# 5.0     399
# 9.0     380
# 7.0     352
# 11.0    320
# 12.0    294
# 14.0    253
# 16.0    242
# 13.0    209
# 10.0    192
# 15.0    129
# 18.0    126
# 19.0    121
# 0.0     120
# 17.0    106
# 20.0     61
# 22.0     47
# 21.0     42
# 23.0     37
# 25.0     24
# 24.0     19
# 28.0     16
# 1.5      12
# 29.0     12
# 27.0     11
# 32.0     10
# 26.0      7
# 30.0      6
# 33.0      6
# 31.0      5
# 34.0      2
# 0.5       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.histplot(yr_exp,color='skyblue',bins=15,kde=True)

plt.title('YEARS OF EXPERIENCE DISTRIBUTION')
plt.xlabel('YOE')
plt.ylabel('Count')



plt.tight_layout()
plt.show()

# %% [markdown]
# ## Count plot: DISPLAYS THE DISTRIBUTION OF DIFFERENT RACES.

# %%
races=df['Race'].dropna().value_counts()
races
# Out:
# Race
# White               1962
# Asian               1603
# Korean               457
# Australian           452
# Chinese              444
# Black                437
# African American     354
# Mixed                334
# Welsh                333
# Hispanic             322
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(races,palette='pastel')

plt.title('distribution of individual by RACE')
plt.xlabel('RACE')
plt.ylabel('COUNT')


plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## scatter plot: SHOWS THE RELATIONSHIP BETWEEN SALARY AND AGE

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Age',y='Salary',color='teal',s=100,hue='Gender')

plt.title('relationship between salry and age')
plt.xlabel('ages')
plt.ylabel('salary')

plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## BOX PLOT and VOILINPLOT: DEPICT THE RELATIONSHIP BETWEEN GENDER AND SALARY

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='Gender',y='Salary',palette='Set3')

plt.title('Relationship between gender and salary')
plt.xlabel('gender')
plt.ylabel('SALARY')


plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(data=df,x='Gender',y='Salary',palette='Set2')

plt.title('violinplot: salary by country')
plt.xlabel('gender')
plt.ylabel('SALARY')


plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## box plot and scatter plot : ILLUSTRATE the connection between education level and salary

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='Education Level',y='Salary',palette='Set3')

plt.title('box plot: Eduaction and salary')
plt.xlabel('education level')
plt.ylabel('SALARY')


plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(data=df,x='Education Level',y='Salary',palette='Set3')

plt.title('violin plot: Eduaction vs salary')
plt.xlabel('education level')
plt.ylabel('SALARY')


plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## bar plot : avg salary for different job titles

# %%
# step 1calculate avg salary per job title
avg_salary = df.groupby('Job Title')['Salary'].mean().reset_index()


#step2  sort avg salary by for  a cleaner data plo
avg_salary = avg_salary.sort_values(by = 'Salary',ascending=False)

#step 3 plot 

plt.figure(figsize=(10,5))
sns.barplot(data=avg_salary,x='Job Title',y='Salary',palette='Blues_d')

plt.title('AVG SALARY BY JOB TITLE ')
plt.xlabel('JOB TITLE')
plt.ylabel('SALARY')


plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ---------- 1. Scatter Plot: Years of Experience vs Salary ----------
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Years of Experience', y='Salary', color='teal')
plt.title('Experience vs Salary')
plt.tight_layout()
plt.show()

# %%
# ---------- 2. Box Plot: Country vs Salary ----------
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Country', y='Salary', palette='Set2')
plt.title('Box Plot - Country vs Salary')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ---------- 3. Violin Plot: Country vs Salary ----------
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Country', y='Salary', palette='Set3')
plt.title('Violin Plot - Country vs Salary')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ---------- 4. Box Plot: Race vs Salary ----------
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Race', y='Salary', palette='Pastel1')
plt.title('Box Plot - Race vs Salary')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ---------- 5. Violin Plot: Race vs Salary ----------
plt.figure(figsize=(6, 5))
sns.violinplot(data=df, x='Race', y='Salary', palette='Pastel2')
plt.title('Violin Plot - Race vs Salary')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ---------- 6. Heatmap: Correlation Matrix ----------
numeric_cols = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_cols.corr()

plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
# ---------- 7. Pair Plot: Numerical Columns ----------
sns.pairplot(numeric_cols)
plt.suptitle('Pair Plot of Numerical Features', y=1.03)
plt.show()
